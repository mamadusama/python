# %% [markdown]
# # E quando o nosso código demora muito? Será que travou? Quanto tempo vai demorar?
#
# ### Biblioteca/Módulo tqdm
#
# - Vamos importar os arquivos csv da Empresa Contoso e tratar como fizemos ao longo desse módulo

# %%
import pandas as pd
#importando os arquivos
vendas_df = pd.read_csv(r'Contoso_Vendas_17.csv', sep=';', encoding="latin1")
produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep=';' , encoding="latin1")
lojas_df = pd.read_csv(r'Contoso_Lojas.csv', sep=';', encoding="latin1")
clientes_df = pd.read_csv(r'Contoso_Clientes.csv', sep=';', encoding="latin1")

produtos_df = produtos_df.rename(columns={"ÿNome do Produto": "Nome do Produto"})
lojas_df = lojas_df.rename(columns={"ÿID Produto": "ID Produto"})
#produtos_df = produtos_df.rename(columns:{"ÿNome do Produto": "Nome do Produto"})

#limpando apenas as colunas que queremos
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

#mesclando e renomeando os dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente').rename(columns={'E-mail': 'E-mail do Cliente'})
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
from tqdm import tqdm
pbar = tqdm(total=len(vendas_df["ID Loja"]), position=0, leave=True)

for i, id_loja in enumerate(vendas_df["ID Loja"]):
    pbar.update()
    if id_loja == 309:
        vendas_df.loc[i,"Quantidade Devolvida"] += 1



display(vendas_df)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████▉| 980266/980642 [02:27<00:00, 7025.63it/s]
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# ...

# %%
frutas = [
    "Banana", "Caju", "Maçã", "Pera", "Abacaxi", "Uva", "Laranja", "Manga", "Melancia", "Morango",
    "Amora", "Framboesa", "Cereja", "Limão", "Tangerina", "Kiwi", "Abacate", "Açaí", "Coco", "Goiaba",
    "Pitanga", "Jabuticaba", "Graviola", "Maracujá", "Romã", "Pêssego", "Figo", "Melão", "Nectarina",
    "Acerola", "Carambola", "Tamarindo", "Cupuaçu", "Pitaya", "Physalis", "Lichia", "Mirtilo", 
    "Cambuci", "Sapoti", "Seriguela", "Pequi", "Buriti", "Guaraná", "Umbu", "Jenipapo", "Mangaba", 
    "Araçá", "Murici", "Camu-camu", "Tucumã", "Coquinho", "Jatobá", "Mamão", "Siriguela", "Durião",
    "Pinha", "Atemoia", "Rambutan", "Langsat", "Ackee", "Longan", "Santol", "Kumquat", "Pomelo",
    "Yuzu", "Calamansi", "Fingerlime", "Noni", "Sapota", "Cherimóia", "Salak", "Canistel", 
    "Maçã-verde", "Banana-nanica", "Banana-prata", "Banana-maçã", "Uva-verde", "Uva-roxa", "Camu-camu", 
    "Cranberry", "Cloudberry", "Pupunha", "Amêndoa", "Noz-pecã", "Castanha-do-pará", "Castanha-de-caju",
    "Macadâmia", "Avelã", "Baru", "Dacryodes", "Noni", "Uvaia", "Pequi", "Cabeludinha", "Laranja-da-terra",
    "Mexerica", "Tangerina-cravo", "Laranja-bahia", "Groselha", "Zimbro", "Alfarroba", "Abiu", "Ameixa",
    "Ameixa-amarela", "Ameixa-vermelha", "Plumcot", "Mirtilo-vermelho", "Arando", "Guariroba", 
    "Quivano", "Jaca", "Pitaia-amarela", "Pitaia-vermelha", "Mamey", "Caimito", "Pitangueira", 
    "Carissa", "Karambola", "Guavira", "Ingá", "Uvai", "Umbu-cajá", "Taperebá", "Abacaxi-roxo", 
    "Pineberry", "Rosa-canina", "Flor-de-jambu", "Tamarillo", "Oiti", "Marolo", "Gabiroba", "Araticum", 
    "Mangostão", "Nance", "Pindoba", "Kaffir-lime", "Medronho", "Cereja-do-rio-grande", "Melancia-amarela",
    "Jambo", "Jambolão", "Murta", "Cabeludinha", "Pau-d’alho", "Fruta-pão", "Jaca-dura", "Jaca-mole", 
    "Biribá", "Bacuri", "Umari", "Caramboleira", "Mucuja", "Maracujá-do-mato", "Fruta-melancia", 
    "Gila", "Erva-mate", "Cambucá", "Jangada", "Guabiroba-do-campo", "Limão-cravo", "Pera-portuguesa",
    "Figo-da-índia", "Nêspera", "Limão-galego", "Maracujá-açu", "Maracujá-roxo", "Grumixama", 
    "Palmito-doce", "Bergamota", "Tangerina-de-casa", "Buchu", "Plátano", "Guelere", "Pamelão",
    "Tucum", "Buritizeiro", "Bacaba", "Uva-japão", "Araticum-do-cerrado", "Acácia", "Pequiá", 
    "Jambo-vermelho", "Cacau", "Fruta-de-lobo", "Coroa-de-frade", "Melão-cantaloupe", "Tomate-de-árvore",
    "Seriguela-dourada", "Seriguela-azul", "Jambinho", "Bacaba-de-leite", "Cabeludinha-gigante",
    "Uva-fresca", "Uva-de-vinho", "Laranja-azeda", "Laranja-doce", "Laranja-seleta", "Abóbora-espaguete",
    "Araticum-seco", "Açaí-da-terra", "Juá", "Urucum", "Flor-da-paixão", "Lulo", "Lulo-de-casa",
    "Fruta-margarida", "Cupuaçu-de-flor", "Azeitona-preta", "Azeitona-verde", "Tâmara", "Pita", 
    "Figo-negro", "Figo-branco", "Manga-palmer", "Manga-haden", "Manga-rosa", "Ameixa-da-índia", 
    "Castanha-do-maranhão", "Noz-moscada", "Jambo-rosado", "Pitangueira-selvagem", "Fruta-de-leite",
    "Groselha-do-campo", "Jucá", "Cambucá-do-mato", "Guaraná-de-pau", "Melão-de-são-caetano",
    "Figo-do-mar", "Cereja-do-japão", "Rambutan-vermelho", "Araçá-vermelho", "Araçá-roxo",
    "Araçá-amarelo", "Caju-anão", "Caju-rosa", "Goiaba-branca", "Goiaba-vermelha", "Goiaba-rosa",
    "Guabiroba-preta", "Guabiroba-amarela", "Guabiroba-verde"
]

# Verificando a quantidade de elementos
#print(f"A lista contém {len(frutas)} frutas.")
# Out:
# A lista contém 241 frutas.

# %% [markdown]
# ### Agora, imagina que a Loja Contoso Roma (ID 222), para tentar burlar o sistema de metas, diminuiu 1 da quantidade devolvida de todas as vendas que ela teve. Descobrindo isso, precisamos ajeitar a base
#
# - Farei com um for, principalmente por motivos didáticos, mas teríamos outras formas de fazer isso também.

# %%
from tqdm import tqdm

pbar = tqdm(total=len(fruta), position=0 , leave=True)

listag=[]

for fruta in frutas:
    pbar.update()
    if "G" in fruta:
        listag.append(fruta)
        
        
        
        
print(listag)
# Out:
#   0%|                                                                                           | 0/15 [00:00<?, ?it/s]
# ['Goiaba', 'Graviola', 'Guaraná', 'Groselha', 'Guariroba', 'Guavira', 'Gabiroba', 'Gila', 'Guabiroba-do-campo', 'Grumixama', 'Guelere', 'Groselha-do-campo', 'Guaraná-de-pau', 'Goiaba-branca', 'Goiaba-vermelha', 'Goiaba-rosa', 'Guabiroba-preta', 'Guabiroba-amarela', 'Guabiroba-verde']
